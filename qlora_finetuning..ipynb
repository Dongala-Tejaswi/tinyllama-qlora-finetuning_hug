# %%
# !pip install torch transformers peft bitsandbytes accelerate datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (2.10.0)
# Requirement already satisfied: transformers in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (5.4.0)
# Requirement already satisfied: peft in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (0.18.1)
# Requirement already satisfied: bitsandbytes in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (0.49.2)
# Requirement already satisfied: accelerate in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (1.13.0)
# Requirement already satisfied: datasets in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (4.8.4)
# Requirement already satisfied: filelock in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from torch) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from torch) (2026.2.0)
# Requirement already satisfied: setuptools in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from torch) (75.3.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from transformers) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex>=2025.10.22 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from transformers) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from transformers) (0.23.1)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.25.2)
# Requirement already satisfied: anyio in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.6)
# Requirement already satisfied: idna in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.10)
# Requirement already satisfied: sniffio in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.14.0)
# Requirement already satisfied: psutil in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from peft) (6.1.0)
# Requirement already satisfied: pyarrow>=21.0.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: xxhash in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: click>=8.0.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from typer->transformers) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from typer->transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from typer->transformers) (0.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from rich>=10.11.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from rich>=10.11.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers) (0.1.2)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Program Files\Python313\python.exe -m pip install --upgrade pip

# %%
# !pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (2.10.0)
# Requirement already satisfied: filelock in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from torch) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from torch) (2026.2.0)
# Requirement already satisfied: setuptools in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from torch) (75.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\tejas\AppData\Roaming\Python\Python313\site-packages (from jinja2->torch) (3.0.2)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Program Files\Python313\python.exe -m pip install --upgrade pip

# %%
import torch
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    Trainer,
    TrainingArguments
)
from peft import LoraConfig,get_peft_model
from datasets import load_dataset
import bitsandbytes as bnb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import torch
#       2 from transformers import (
#       3     AutoTokenizer,
#       4     AutoModelForCausalLM,
#       5     Trainer,
#       6     TrainingArguments
#       7 )
#       8 from peft import LoraConfig,get_peft_model
#
# ModuleNotFoundError: No module named 'torch'
